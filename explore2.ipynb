# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df2 = pd.read_csv('data/Raw/Raw_experiments_species.csv')
df2.shape
# Out:
# /tmp/ipykernel_84523/1391126765.py:1: DtypeWarning: Columns (23,26,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('data/Raw/Raw_experiments_species.csv')
# (12798, 124)
