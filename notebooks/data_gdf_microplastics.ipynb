# %%
import pandas as pd
import geopandas as gpd

# %%
df_mar = pd.read_csv("../data/Raw/Marine_Microplastics_WGS84_8553846406879449657.csv")
df_mar.head()
# Out:
#    OBJECTID  Latitude (degree)  Longitude(degree)           Ocean Region  \
# 0         1              45.28             -60.29  Atlantic Ocean    NaN
# 1         2              40.93             -70.65  Atlantic Ocean    NaN
# 2         3              40.93             -70.65  Atlantic Ocean    NaN
# 3         4              40.30             -69.77  Atlantic Ocean    NaN
# 4         5              39.88             -67.15  Atlantic Ocean    NaN
#
#   Subregion Country State Beach Location Marine Setting  ...  \
# 0       NaN     NaN   NaN            NaN    Ocean water  ...
# 1       NaN     NaN   NaN            NaN    Ocean water  ...
# 2       NaN     NaN   NaN            NaN    Ocean water  ...
# 3       NaN     NaN   NaN            NaN    Ocean water  ...
# 4       NaN     NaN   NaN            NaN    Ocean water  ...
#
#                                        DOI               ORGANIZATION  \
# 0  https://doi.org/10.1126/science.1192321  Sea Education Association
# 1  https://doi.org/10.1126/science.1192321  Sea Education Association
# 2  https://doi.org/10.1126/science.1192321  Sea Education Association
# 3  https://doi.org/10.1126/science.1192321  Sea Education Association
# 4  https://doi.org/10.1126/science.1192321  Sea Education Association
#
#    KEYWORDS NCEI Accession No  \
# 0       SEA            211007
# 1       SEA            211007
# 2       SEA            211007
# 3       SEA            211007
# 4       SEA            211007
#
#                              NCEI Accession No. Link  \
# 0  https://www.ncei.noaa.gov/access/metadata/land...
# 1  https://www.ncei.noaa.gov/access/metadata/land...
# 2  https://www.ncei.noaa.gov/access/metadata/land...
# 3  https://www.ncei.noaa.gov/access/metadata/land...
# 4  https://www.ncei.noaa.gov/access/metadata/land...
#
#                                      Symbology  \
# 0  Ocean Surface, Very Low, 0-0.0005 pieces/m3
# 1   Ocean Surface, Low, 0.0005-0.005 pieces/m3
# 2   Ocean Surface, Low, 0.0005-0.005 pieces/m3
# 3  Ocean Surface, Very Low, 0-0.0005 pieces/m3
# 4  Ocean Surface, Very Low, 0-0.0005 pieces/m3
#
#                                GlobalID       Date (MM-DD-YYYY)      x      y
# 0  2ce1d1d4-4231-4ab8-af74-0b7fbb1e028b   7/13/1989 12:00:00 AM -60.29  45.28
# 1  8e3c8426-5ab0-421e-abb2-6b90197ada7a  10/12/1989 12:00:00 AM -70.65  40.93
# 2  99bda337-9f0c-4f58-9960-8b00c1110a7c  10/12/1989 12:00:00 AM -70.65  40.93
# 3  1f20e926-2a84-4e42-8478-8a5af5aecacc  10/12/1989 12:00:00 AM -69.77  40.30
# 4  a0df6bee-9c60-4621-a0bc-3329e3f11720  10/15/1989 12:00:00 AM -67.15  39.88
#
# [5 rows x 36 columns]

# %%
df_mar.shape
# Out:
# (22530, 36)

# %%
df_mar.duplicated().sum()
# Out:
# np.int64(0)

# %%
for col in df_mar.columns:
    print(col)
# Out:
# OBJECTID
# Latitude (degree)
# Longitude(degree)
# Ocean
# Region
# Subregion
# Country
# State
# Beach Location
# Marine Setting
# Ocean Bottom Depth (m)
# Water Sample Depth (m)
# Sediment Sample Depth (m)
# Sampling Method
# Mesh size (mm)
# Transect No
# Sampling point on beach
# Volunteers Number
# Collecting Time (min)
# Standardized Nurdle  Amount
# Microplastics measurement
# Unit
# Concentration class range
# Concentration class text
# Short Reference
# Long Reference
# DOI
# ORGANIZATION
# KEYWORDS
# NCEI Accession No
# NCEI Accession No. Link
# Symbology
# GlobalID
# Date (MM-DD-YYYY)
# x
# y

# %%
df_mar = df_mar[[
    "Microplastics measurement",
    "Unit",
    "Concentration class range",
    "Mesh size (mm)",
    "Latitude (degree)",
    "Longitude(degree)"
]]

df_mar = df_mar.rename(columns={
    "Latitude (degree)": "lat",
    "Longitude(degree)": "lon",
    "Microplastics measurement": "microplastics_measurement",
    "Concentration class range": "concentration_class_range",
    "Mesh size (mm)": "mesh_size_mm"
})

df_mar.columns = df_mar.columns.str.lower()

# Asegurar coordenadas como float
df_mar["lon"] = df_mar["lon"].astype(float)
df_mar["lat"] = df_mar["lat"].astype(float)

df_mar.head(10)
# Out:
#    microplastics_measurement       unit concentration_class_range  \
# 0                   0.000000  pieces/m3                  0-0.0005
# 1                   0.002276  pieces/m3              0.0005-0.005
# 2                   0.004320  pieces/m3              0.0005-0.005
# 3                   0.000000  pieces/m3                  0-0.0005
# 4                   0.000000  pieces/m3                  0-0.0005
# 5                   0.043196  pieces/m3                   0.005-1
# 6                   0.535636  pieces/m3                   0.005-1
# 7                   0.069116  pieces/m3                   0.005-1
# 8                   0.084232  pieces/m3                   0.005-1
# 9                   0.299496  pieces/m3                   0.005-1
#
#    mesh_size_mm    lat    lon
# 0         0.335  45.28 -60.29
# 1         0.335  40.93 -70.65
# 2         0.335  40.93 -70.65
# 3         0.335  40.30 -69.77
# 4         0.335  39.88 -67.15
# 5         0.335  37.83 -63.73
# 6         0.335  37.83 -63.73
# 7         0.335  36.90 -63.38
# 8         0.335  36.90 -63.38
# 9         0.335  35.70 -61.98

# %%
df_mar.duplicated().sum()
# Out:
# np.int64(3208)

# %%
dups = df_mar[df_mar.duplicated()]
dups.head(10)
# Out:
#     microplastics_measurement       unit concentration_class_range  \
# 18                    0.00000  pieces/m3                  0-0.0005
# 34                    0.00000  pieces/m3                  0-0.0005
# 36                    0.00000  pieces/m3                  0-0.0005
# 43                    0.00000  pieces/m3                  0-0.0005
# 47                    0.00000  pieces/m3                  0-0.0005
# 49                    0.00000  pieces/m3                  0-0.0005
# 51                    0.00432  pieces/m3              0.0005-0.005
# 57                    0.00000  pieces/m3                  0-0.0005
# 59                    0.00000  pieces/m3                  0-0.0005
# 61                    0.00000  pieces/m3                  0-0.0005
#
#     mesh_size_mm    lat    lon
# 18         0.335  17.80 -64.32
# 34         0.335  15.10 -61.98
# 36         0.335  13.98 -61.70
# 43         0.335  13.05 -63.12
# 47         0.335  14.68 -64.43
# 49         0.335  15.80 -65.30
# 51         0.335  16.48 -65.90
# 57         0.335  17.90 -67.62
# 59         0.335  17.90 -67.82
# 61         0.335  18.03 -68.42

# %%
df_mar = df_mar.drop_duplicates()
df_mar.shape
# Out:
# (19322, 6)

# %%
df_mar = df_mar.dropna(subset=["lat", "lon"])

# %%
df_mar.shape
# Out:
# (19322, 6)

# %%
df_mar.head(10)
# Out:
#    microplastics_measurement       unit concentration_class_range  \
# 0                   0.000000  pieces/m3                  0-0.0005
# 1                   0.002276  pieces/m3              0.0005-0.005
# 2                   0.004320  pieces/m3              0.0005-0.005
# 3                   0.000000  pieces/m3                  0-0.0005
# 4                   0.000000  pieces/m3                  0-0.0005
# 5                   0.043196  pieces/m3                   0.005-1
# 6                   0.535636  pieces/m3                   0.005-1
# 7                   0.069116  pieces/m3                   0.005-1
# 8                   0.084232  pieces/m3                   0.005-1
# 9                   0.299496  pieces/m3                   0.005-1
#
#    mesh_size_mm    lat    lon
# 0         0.335  45.28 -60.29
# 1         0.335  40.93 -70.65
# 2         0.335  40.93 -70.65
# 3         0.335  40.30 -69.77
# 4         0.335  39.88 -67.15
# 5         0.335  37.83 -63.73
# 6         0.335  37.83 -63.73
# 7         0.335  36.90 -63.38
# 8         0.335  36.90 -63.38
# 9         0.335  35.70 -61.98

# %%
df_mar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19322 entries, 0 to 22529
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   microplastics_measurement  14197 non-null  float64
#  1   unit                       19322 non-null  object
#  2   concentration_class_range  19322 non-null  object
#  3   mesh_size_mm               14155 non-null  float64
#  4   lat                        19322 non-null  float64
#  5   lon                        19322 non-null  float64
# dtypes: float64(4), object(2)
# memory usage: 1.0+ MB

# %%
df_mar.to_csv("../data/GeoDataFrame/dataframe/df_mar.csv", index = False)

# %% [markdown]
# #### GeoDataFrame

# %%
gdf_mar = gpd.GeoDataFrame(
    df_mar,
    geometry=gpd.points_from_xy(df_mar.lon, df_mar.lat),
    crs="EPSG:4326"
)

# %%
# coordenadas fuera de rango
gdf_mar = gdf_mar[
    gdf_mar.lon.between(-180, 180) &
    gdf_mar.lat.between(-90, 90)
]

# eliminar geometrías inválidas
gdf_mar = gdf_mar[gdf_mar.is_valid]

# %%
gdf_mar.shape
# Out:
# (19322, 7)

# %%
gdf_mar.to_file("../data/GeoDataFrame/gdf_microplastics.gpkg", driver="GPKG")
