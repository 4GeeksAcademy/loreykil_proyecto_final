# %%
import geopandas as gpd
import pandas as pd
import numpy as np

from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Paso 1: Dataset Base: IUCN.

# %%
# Leemos el dataset, que viene en puntos
# El CRS EPSG:4326 significa latitud/longitud
iucn = gpd.read_file("../data/GeoDataFrame/gdf_species.gpkg").to_crs("EPSG:4326")

# %%
# Seleccionamos las columnas que nos interesan
iucn = iucn[[
    "sci_name",
    "redlistCategory",
    "geometry"
]].copy()

# %%
# Creamos una columna con el ID
iucn["iucn_id"] = iucn.index

# %%
# Creamos columna con el índice de vulneravilidad:

status_map = {"CR":4, "EN":3, "VU":2, "NT":1}

iucn["vuln"] = (
    iucn["redlistCategory"]
    .map(status_map)
    .fillna(0)
)
iucn
# Out:
#                   sci_name redlistCategory                    geometry  \
# 0         Hubbsina turneri              CR   POINT (-101.4795 19.8745)
# 1         Hubbsina turneri              CR   POINT (-101.7773 19.8256)
# 2         Hubbsina turneri              CR   POINT (-101.7876 19.8273)
# 3      Ictalurus mexicanus              VU  POINT (-99.35417 21.98083)
# 4      Ictalurus mexicanus              VU            POINT (-99.3 22)
# ...                    ...             ...                         ...
# 70268  Macrobrachium thysi              VU    POINT (-3.00185 5.14407)
# 70269  Macrobrachium thysi              VU    POINT (-3.52102 5.49955)
# 70270  Macrobrachium thysi              VU    POINT (-3.51293 5.49003)
# 70271  Macrobrachium thysi              VU    POINT (-4.12282 5.40212)
# 70272  Macrobrachium thysi              VU    POINT (-4.05195 5.38445)
#
#        iucn_id  vuln
# 0            0     4
# 1            1     4
# 2            2     4
# 3            3     2
# 4            4     2
# ...        ...   ...
# 70268    70268     2
# 70269    70269     2
# 70270    70270     2
# 70271    70271     2
# 70272    70272     2
#
# [70273 rows x 5 columns]

# %% [markdown]
# Salida:
#
# iucn = dataset base, ≥60k filas

# %% [markdown]
# # Paso 2. NOAA (microplásticos)

# %%
# NOAA también son puntos
noaa = gpd.read_file("../data/GeoDataFrame/gdf_microplastics.gpkg").to_crs("EPSG:4326")
noaa
# Out:
#        microplastics_measurement              unit concentration_class_range  \
# 0                       0.000000         pieces/m3                  0-0.0005
# 1                       0.002276         pieces/m3              0.0005-0.005
# 2                       0.004320         pieces/m3              0.0005-0.005
# 3                       0.000000         pieces/m3                  0-0.0005
# 4                       0.000000         pieces/m3                  0-0.0005
# ...                          ...               ...                       ...
# 19317                 188.300000  pieces kg-1 d.w.                   150-200
# 19318                 155.270000  pieces kg-1 d.w.                   150-200
# 19319                  58.070000  pieces kg-1 d.w.                    20-150
# 19320                 210.000000  pieces kg-1 d.w.                      >200
# 19321                 208.330000  pieces kg-1 d.w.                      >200
#
#        mesh_size_mm        lat        lon                geometry
# 0            0.3350  45.280000 -60.290000    POINT (-60.29 45.28)
# 1            0.3350  40.930000 -70.650000    POINT (-70.65 40.93)
# 2            0.3350  40.930000 -70.650000    POINT (-70.65 40.93)
# 3            0.3350  40.300000 -69.770000     POINT (-69.77 40.3)
# 4            0.3350  39.880000 -67.150000    POINT (-67.15 39.88)
# ...             ...        ...        ...                     ...
# 19317        0.0007  -5.933333  39.360000  POINT (39.36 -5.93333)
# 19318        0.0007  -5.500000  39.120000      POINT (39.12 -5.5)
# 19319        0.0007  -6.450000  39.466667  POINT (39.46667 -6.45)
# 19320        0.0007  -6.320000  39.210000     POINT (39.21 -6.32)
# 19321        0.0007  -6.110000  39.150000     POINT (39.15 -6.11)
#
# [19322 rows x 7 columns]

# %%
noaa["microplastics_measurement"].describe()
# Out:
# count     14197.000000
# mean        503.483545
# std        9241.272331
# min           0.000000
# 25%           0.002000
# 50%           0.017280
# 75%           0.322781
# max      800000.000000
# Name: microplastics_measurement, dtype: float64

# %%
noaa = noaa[noaa["unit"] == "pieces/m3"].copy()

# %%
noaa["unit"].unique()
# Out:
# array(['pieces/m3'], dtype=object)

# %%
noaa["microplastics_measurement"].describe()
# Out:
# count     13726.000000
# mean        509.884284
# std        9391.709753
# min           0.000000
# 25%           0.001627
# 50%           0.015120
# 75%           0.220000
# max      800000.000000
# Name: microplastics_measurement, dtype: float64

# %% [markdown]
# Hay filas en las que "microplastics measurement" es NaN y no nos interesan. Nos quedamos solo con las filas con datos medidos

# %%
noaa_valid = noaa[noaa["microplastics_measurement"].notna()].copy()
noaa_nan = noaa[noaa["microplastics_measurement"].isna()].copy()
noaa_nan
# Out:
# Empty GeoDataFrame
# Columns: [microplastics_measurement, unit, concentration_class_range, mesh_size_mm, lat, lon, geometry]
# Index: []

# %% [markdown]
# Convertimos "noaa_valid" en el nuevo dataset de "noaa"

# %%
noaa = noaa_valid[[
    "microplastics_measurement",
    "geometry"
]].copy()

# Renombramos la columna para tener a la vista las unidades de medida
noaa = noaa.rename(columns={
    "microplastics_measurement": "mp_pieces_m3"
})

# %% [markdown]
# #### Asignar microplásticos por cercanía

# %%
# Pasar a metros
# El CRS EPSG:3857 signiifica proyección métrica
iucn_m = iucn.to_crs("EPSG:3857")
noaa_m = noaa.to_crs("EPSG:3857")

# %%
# Nearest spatial join
iucn_noaa = gpd.sjoin_nearest(
    iucn_m,
    noaa_m,
    how="left",
    distance_col="dist_m"
)
iucn_noaa
# Out:
#                   sci_name redlistCategory                          geometry  \
# 0         Hubbsina turneri              CR  POINT (-11296646.266 2258169.64)
# 0         Hubbsina turneri              CR  POINT (-11296646.266 2258169.64)
# 0         Hubbsina turneri              CR  POINT (-11296646.266 2258169.64)
# 0         Hubbsina turneri              CR  POINT (-11296646.266 2258169.64)
# 1         Hubbsina turneri              CR  POINT (-11329797.21 2252382.257)
# ...                    ...             ...                               ...
# 70268  Macrobrachium thysi              VU    POINT (-334164.413 573406.106)
# 70269  Macrobrachium thysi              VU    POINT (-391958.153 613149.338)
# 70270  Macrobrachium thysi              VU    POINT (-391057.579 612084.684)
# 70271  Macrobrachium thysi              VU    POINT (-458950.223 602254.212)
# 70272  Macrobrachium thysi              VU     POINT (-451061.011 600278.45)
#
#        iucn_id  vuln  index_right  mp_pieces_m3         dist_m
# 0            0     4        13103   1410.437236  244627.454273
# 0            0     4        13102    705.218618  244627.454273
# 0            0     4        13104   2115.655853  244627.454273
# 0            0     4        13101      0.000000  244627.454273
# 1            1     4        13103   1410.437236  237016.489842
# ...        ...   ...          ...           ...            ...
# 70268    70268     2        11468      0.038661  959001.335033
# 70269    70269     2        11468      0.038661  929073.410690
# 70270    70270     2        11468      0.038661  929269.937379
# 70271    70271     2        11468      0.038661  866968.071829
# 70272    70272     2        11468      0.038661  872433.478446
#
# [81287 rows x 8 columns]

# %% [markdown]
# Ahora cada especie tiene:
#
# mp_pieces_m3 del NOAA más cercano
#
# dist_m (metros)

# %%
# Resolvemos duplicados por microplasticos que estan a la misma distancia, nos quedamos con
iucn_noaa_clean = (
    iucn_noaa
    .sort_values("mp_pieces_m3", ascending=False)
    .drop_duplicates(subset="iucn_id", keep="first")
)
iucn_noaa_clean["iucn_id"].value_counts().max() # Comprobación de que no hay duplicados (debe salir 1)
# Out:
# np.int64(1)

# %% [markdown]
# Cuando una especie (iucn_id) tiene varias filas (duplicados), nos quedamos con aquella cuyo valor de mp_pieces_m3 es el más alto.

# %%
iucn_noaa_clean = iucn_noaa_clean.sort_values("iucn_id")

# %%
iucn_noaa = iucn_noaa_clean
iucn_noaa
# Out:
#                   sci_name redlistCategory                           geometry  \
# 0         Hubbsina turneri              CR   POINT (-11296646.266 2258169.64)
# 1         Hubbsina turneri              CR   POINT (-11329797.21 2252382.257)
# 2         Hubbsina turneri              CR  POINT (-11330943.801 2252583.424)
# 3      Ictalurus mexicanus              VU  POINT (-11060055.613 2509223.803)
# 4      Ictalurus mexicanus              VU  POINT (-11054025.436 2511525.235)
# ...                    ...             ...                                ...
# 70268  Macrobrachium thysi              VU     POINT (-334164.413 573406.106)
# 70269  Macrobrachium thysi              VU     POINT (-391958.153 613149.338)
# 70270  Macrobrachium thysi              VU     POINT (-391057.579 612084.684)
# 70271  Macrobrachium thysi              VU     POINT (-458950.223 602254.212)
# 70272  Macrobrachium thysi              VU      POINT (-451061.011 600278.45)
#
#        iucn_id  vuln  index_right  mp_pieces_m3         dist_m
# 0            0     4        13104   2115.655853  244627.454273
# 1            1     4        13104   2115.655853  237016.489842
# 2            2     4        13104   2115.655853  237235.709534
# 3            3     2        13032   2820.874471  176956.192726
# 4            4     2        13032   2820.874471  170585.675721
# ...        ...   ...          ...           ...            ...
# 70268    70268     2        11468      0.038661  959001.335033
# 70269    70269     2        11468      0.038661  929073.410690
# 70270    70270     2        11468      0.038661  929269.937379
# 70271    70271     2        11468      0.038661  866968.071829
# 70272    70272     2        11468      0.038661  872433.478446
#
# [70273 rows x 8 columns]

# %% [markdown]
# # Paso 4. Ajustar exposición por distancia

# %%
# Pasamos distancia a kilometros
iucn_noaa["distance_km"] = iucn_noaa["dist_m"] / 1000

# %% [markdown]
# ### mp_effective = mp_pieces_m3 x e ^ −(distance_km/DECAY_KM)
# 	​

# %% [markdown]
# mp_pieces_m3 es el valor máximo de impacto posible, cuando la distancia es 0 km
#
# distance_km cuanto mayor es esta distancia, menos representativa es esa medición para la especie
#
# DECAY_KM A una distancia igual a km, el efecto se reduce a 1/e ≈ 37%.
#
# e (Número de Euler ~ 2.718) Aparece en procesos donde hay decaimiento continuo y suave
#
# e ^ −(distance_km/DECAY_KM) función de decaimiento exponencial. Asume que el efecto se pierde progresivamente.

# %%
''' Explicación gráfica de lo que hace matemáticamente el término exponencial de la fórmula.

impacto
1.0 |\
    | \
0.5 |  \
    |    \
0.1 |      \
    |         \____
    +----------------
        distancia (km)'''
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\_'
# <>:1: SyntaxWarning: invalid escape sequence '\_'
# /tmp/ipykernel_3000/863413610.py:1: SyntaxWarning: invalid escape sequence '\_'
#   ''' Explicación gráfica de lo que hace matemáticamente el término exponencial de la fórmula.
# ' Explicación gráfica de lo que hace matemáticamente el término exponencial de la fórmula.\n\nimpacto\n1.0 |    | 0.5 |      |    0.1 |          |         \\____\n    +----------------\n        distancia (km)'

# %%
# Decaimiento exponencial. si el microplástico está a mayor distancia, el impacto va a ser menor
# Evitar asumir que un muestreo lejano afecta igual.

DECAY_KM = 50 

iucn_noaa["mp_effective_m3"] = (
    iucn_noaa["mp_pieces_m3"] *
    np.exp(- iucn_noaa["distance_km"] / DECAY_KM)
)
iucn_noaa
# Out:
#                   sci_name redlistCategory                           geometry  \
# 0         Hubbsina turneri              CR   POINT (-11296646.266 2258169.64)
# 1         Hubbsina turneri              CR   POINT (-11329797.21 2252382.257)
# 2         Hubbsina turneri              CR  POINT (-11330943.801 2252583.424)
# 3      Ictalurus mexicanus              VU  POINT (-11060055.613 2509223.803)
# 4      Ictalurus mexicanus              VU  POINT (-11054025.436 2511525.235)
# ...                    ...             ...                                ...
# 70268  Macrobrachium thysi              VU     POINT (-334164.413 573406.106)
# 70269  Macrobrachium thysi              VU     POINT (-391958.153 613149.338)
# 70270  Macrobrachium thysi              VU     POINT (-391057.579 612084.684)
# 70271  Macrobrachium thysi              VU     POINT (-458950.223 602254.212)
# 70272  Macrobrachium thysi              VU      POINT (-451061.011 600278.45)
#
#        iucn_id  vuln  index_right  mp_pieces_m3         dist_m  distance_km  \
# 0            0     4        13104   2115.655853  244627.454273   244.627454
# 1            1     4        13104   2115.655853  237016.489842   237.016490
# 2            2     4        13104   2115.655853  237235.709534   237.235710
# 3            3     2        13032   2820.874471  176956.192726   176.956193
# 4            4     2        13032   2820.874471  170585.675721   170.585676
# ...        ...   ...          ...           ...            ...          ...
# 70268    70268     2        11468      0.038661  959001.335033   959.001335
# 70269    70269     2        11468      0.038661  929073.410690   929.073411
# 70270    70270     2        11468      0.038661  929269.937379   929.269937
# 70271    70271     2        11468      0.038661  866968.071829   866.968072
# 70272    70272     2        11468      0.038661  872433.478446   872.433478
#
#        mp_effective_m3
# 0         1.587223e+01
# 1         1.848187e+01
# 2         1.840102e+01
# 3         8.191469e+01
# 4         9.304551e+01
# ...                ...
# 70268     1.809228e-10
# 70269     3.291880e-10
# 70270     3.278966e-10
# 70271     1.139946e-09
# 70272     1.021909e-09
#
# [70273 rows x 10 columns]

# %% [markdown]
# # Paso 5. TOMEx: de concentracion (dosis) a toxicidad

# %%
pd.set_option("display.max_columns", None)

# %%
# Cargar TOMEx species
tomex = pd.read_csv("../data/Raw/ToMEx_sp_ml.csv")
tomex
# Out:
#                             DOI                 Authors  Year  \
# 0            10.7717/peerj.4601  Aljaibachi & Callaghan  2018
# 1            10.7717/peerj.4601  Aljaibachi & Callaghan  2018
# 2            10.7717/peerj.4601  Aljaibachi & Callaghan  2018
# 3            10.7717/peerj.4601  Aljaibachi & Callaghan  2018
# 4            10.7717/peerj.4601  Aljaibachi & Callaghan  2018
# ...                         ...                     ...   ...
# 3898  10.1016/j.fsi.2021.04.014                  Zwollo  2021
# 3899  10.1016/j.fsi.2021.04.014                  Zwollo  2021
# 3900  10.1016/j.fsi.2021.04.014                  Zwollo  2021
# 3901  10.1016/j.fsi.2021.04.014                  Zwollo  2021
# 3902  10.1016/j.fsi.2021.04.014                  Zwollo  2021
#
#                   Species Organism Group Environment    Life Stage  \
# 0           Daphnia magna      Crustacea  Freshwater         adult
# 1           Daphnia magna      Crustacea  Freshwater         adult
# 2           Daphnia magna      Crustacea  Freshwater         adult
# 3           Daphnia magna      Crustacea  Freshwater         adult
# 4           Daphnia magna      Crustacea  Freshwater         early
# ...                   ...            ...         ...           ...
# 3898  Oncorhynchus mykiss           Fish  Freshwater  Not Reported
# 3899  Oncorhynchus mykiss           Fish  Freshwater  Not Reported
# 3900  Oncorhynchus mykiss           Fish  Freshwater  Not Reported
# 3901  Oncorhynchus mykiss           Fish  Freshwater  Not Reported
# 3902  Oncorhynchus mykiss           Fish  Freshwater  Not Reported
#
#      In vitro/in vivo           Sex  Estimated Body Length (cm)  \
# 0             In Vivo  Not Reported                        0.50
# 1             In Vivo  Not Reported                        0.50
# 2             In Vivo  Not Reported                        0.50
# 3             In Vivo  Not Reported                        0.50
# 4             In Vivo  Not Reported                        0.08
# ...               ...           ...                         ...
# 3898         In Vitro  Not Reported                         NaN
# 3899         In Vitro  Not Reported                         NaN
# 3900         In Vitro  Not Reported                         NaN
# 3901         In Vitro  Not Reported                         NaN
# 3902         In Vitro  Not Reported                         NaN
#
#       Estimated Maximum Ingestible Size (mm) Experiment Type Exposure Route  \
# 0                                   0.341121   Particle Only          water
# 1                                   0.341121   Particle Only          water
# 2                                   0.341121   Particle Only          water
# 3                                   0.341121   Particle Only          water
# 4                                   0.061585   Particle Only          water
# ...                                      ...             ...            ...
# 3898                                     NaN   Particle Only          water
# 3899                                     NaN   Particle Only          water
# 3900                                     NaN   Particle Only          water
# 3901                                     NaN   Particle Only          water
# 3902                                     NaN   Particle Only          water
#
#      Particle Mix? Negative Control Reference Particle     Exposure Media  \
# 0               No                Y                  N  artificial_medium
# 1               No                Y                  N  artificial_medium
# 2               No                Y                  N  artificial_medium
# 3               No                Y                  N  artificial_medium
# 4               No                Y                  N  artificial_medium
# ...            ...              ...                ...                ...
# 3898            No              Yes                 No  artificial_medium
# 3899            No              Yes                 No  artificial_medium
# 3900            No              Yes                 No  artificial_medium
# 3901            No              Yes                 No  artificial_medium
# 3902            No              Yes                 No  artificial_medium
#
#            Solvent     Detergent  pH  Salinity (ppt)  Temperature (Avg)  \
# 0     Not Reported  Not Reported NaN             NaN               20.0
# 1     Not Reported  Not Reported NaN             NaN               20.0
# 2     Not Reported  Not Reported NaN             NaN               20.0
# 3     Not Reported  Not Reported NaN             NaN               20.0
# 4     Not Reported  Not Reported NaN             NaN               20.0
# ...            ...           ...  ..             ...                ...
# 3898          DMSO  Not Reported NaN             NaN               18.0
# 3899          DMSO  Not Reported NaN             NaN               18.0
# 3900          DMSO  Not Reported NaN             NaN               18.0
# 3901          DMSO  Not Reported NaN             NaN               18.0
# 3902          DMSO  Not Reported NaN             NaN               18.0
#
#       Temperature (Min) Temperature (Max)  Exposure Duration (days)  \
# 0                   NaN               NaN                      21.0
# 1                   NaN               NaN                      21.0
# 2                   NaN               NaN                      21.0
# 3                   NaN               NaN                      21.0
# 4                   NaN               NaN                      21.0
# ...                 ...               ...                       ...
# 3898                NaN               NaN                       3.0
# 3899                NaN               NaN                       3.0
# 3900                NaN               NaN                       3.0
# 3901                NaN               NaN                       3.0
# 3902                NaN               NaN                       3.0
#
#       Recovery (Days) Acute/Chronic  Number of Doses  Replicates  \
# 0                 NaN       Chronic                2         8.0
# 1                 NaN       Chronic                2         8.0
# 2                 NaN       Chronic                2         8.0
# 3                 NaN       Chronic                2         8.0
# 4                 NaN       Chronic                2         8.0
# ...               ...           ...              ...         ...
# 3898              NaN         Acute                5         1.0
# 3899              NaN         Acute                5         1.0
# 3900              NaN         Acute                5         1.0
# 3901              NaN         Acute                5         1.0
# 3902              NaN         Acute                5         1.0
#
#         Sample Size  Dosing Frequency Chemicals Added  \
# 0                 1               2.0    Not Reported
# 1                 1               2.0    Not Reported
# 2                 1               2.0    Not Reported
# 3                 1               2.0    Not Reported
# 4                 1               2.0    Not Reported
# ...             ...               ...             ...
# 3898  10^7 cells/mL               0.0    Not Reported
# 3899  10^7 cells/mL               0.0    Not Reported
# 3900  10^7 cells/mL               0.0    Not Reported
# 3901  10^7 cells/mL               0.0    Not Reported
# 3902  10^7 cells/mL               0.0    Not Reported
#
#       Added Chemical Dose (nominal)  Added Chemical Dose (measured)  \
# 0                                 0                             NaN
# 1                                 0                             NaN
# 2                                 0                             NaN
# 3                                 0                             NaN
# 4                                 0                             NaN
# ...                             ...                             ...
# 3898                              0                             NaN
# 3899                              0                             NaN
# 3900                              0                             NaN
# 3901                              0                             NaN
# 3902                              0                             NaN
#
#       Plotted Dose Values  Unaligned Dose Values   Dose Metric  Alignment  \
# 0              316.036244             316.036244  Particles/mL  Unaligned
# 1             2523.742669            2523.742669  Particles/mL  Unaligned
# 2              316.036244             316.036244  Particles/mL  Unaligned
# 3             2523.742669            2523.742669  Particles/mL  Unaligned
# 4              316.036244             316.036244  Particles/mL  Unaligned
# ...                   ...                    ...           ...        ...
# 3898             4.049116               4.049116  Particles/mL  Unaligned
# 3899            40.491163              40.491163  Particles/mL  Unaligned
# 3900           404.911625             404.911625  Particles/mL  Unaligned
# 3901          4049.116254            4049.116254  Particles/mL  Unaligned
# 3902         40491.162542           40491.162542  Particles/mL  Unaligned
#
#      Effect     Direction Broad Endpoint Category Specific Endpoint Category  \
# 0       Yes      increase                 Fitness                  Mortality
# 1       Yes      increase                 Fitness                  Mortality
# 2        No  Not Reported                 Fitness               Reproduction
# 3        No  Not Reported                 Fitness               Reproduction
# 4       Yes      increase                 Fitness                  Mortality
# ...     ...           ...                     ...                        ...
# 3898    Yes      decrease                  Immune               Immune Cells
# 3899    Yes      decrease                  Immune               Immune Cells
# 3900    Yes      decrease                  Immune               Immune Cells
# 3901    Yes      decrease                  Immune               Immune Cells
# 3902    Yes      decrease                  Immune               Immune Cells
#
#                                 Endpoint Level of Biological Organization  \
# 0                              Mortality                         Organism
# 1                              Mortality                         Organism
# 2                    Number of Offspring                         Organism
# 3                    Number of Offspring                         Organism
# 4                              Mortality                         Organism
# ...                                  ...                              ...
# 3898  B cell abundance (immature/mature)                             Cell
# 3899  B cell abundance (immature/mature)                             Cell
# 3900  B cell abundance (immature/mature)                             Cell
# 3901  B cell abundance (immature/mature)                             Cell
# 3902  B cell abundance (immature/mature)                             Cell
#
#      Target Cell or Tissue Effect Metric      Polymer   Shape  \
# 0             Not Reported           NaN  Polystyrene  Sphere
# 1             Not Reported           NaN  Polystyrene  Sphere
# 2             Not Reported           NaN  Polystyrene  Sphere
# 3             Not Reported           NaN  Polystyrene  Sphere
# 4             Not Reported           NaN  Polystyrene  Sphere
# ...                    ...           ...          ...     ...
# 3898                B cell          LOEC  Polystyrene  Sphere
# 3899                B cell           NaN  Polystyrene  Sphere
# 3900                B cell           NaN  Polystyrene  Sphere
# 3901                B cell           NaN  Polystyrene  Sphere
# 3902                B cell           NaN  Polystyrene  Sphere
#
#       Density (g/cm^3) Density, reported or estimated Charge  \
# 0                 1.05                       reported    NaN
# 1                 1.05                       reported    NaN
# 2                 1.05                       reported    NaN
# 3                 1.05                       reported    NaN
# 4                 1.05                       reported    NaN
# ...                ...                            ...    ...
# 3898              1.05                       reported    NaN
# 3899              1.05                       reported    NaN
# 3900              1.05                       reported    NaN
# 3901              1.05                       reported    NaN
# 3902              1.05                       reported    NaN
#
#       Zeta Potential (mV) Zeta Potential Media Functional Group  \
# 0                     NaN                  NaN             COOH
# 1                     NaN                  NaN             COOH
# 2                     NaN                  NaN             COOH
# 3                     NaN                  NaN             COOH
# 4                     NaN                  NaN             COOH
# ...                   ...                  ...              ...
# 3898                  NaN                  NaN              NaN
# 3899                  NaN                  NaN              NaN
# 3900                  NaN                  NaN              NaN
# 3901                  NaN                  NaN              NaN
# 3902                  NaN                  NaN              NaN
#
#       Particle Length (μm)  Particle Width (μm) Size Category  \
# 0                      2.0                  2.0   1µm < 100µm
# 1                      2.0                  2.0   1µm < 100µm
# 2                      2.0                  2.0   1µm < 100µm
# 3                      2.0                  2.0   1µm < 100µm
# 4                      2.0                  2.0   1µm < 100µm
# ...                    ...                  ...           ...
# 3898                  16.5                 16.5   1µm < 100µm
# 3899                  16.5                 16.5   1µm < 100µm
# 3900                  16.5                 16.5   1µm < 100µm
# 3901                  16.5                 16.5   1µm < 100µm
# 3902                  16.5                 16.5   1µm < 100µm
#
#       Particle Surface Area (μm^2)  Particle Volume (μm^3)  \
# 0                        12.566371                 4.18879
# 1                        12.566371                 4.18879
# 2                        12.566371                 4.18879
# 3                        12.566371                 4.18879
# 4                        12.566371                 4.18879
# ...                            ...                     ...
# 3898                    855.298600              2352.07115
# 3899                    855.298600              2352.07115
# 3900                    855.298600              2352.07115
# 3901                    855.298600              2352.07115
# 3902                    855.298600              2352.07115
#
#       Particle Mass (mg) Weathered or Biofouled? Size Validated?  \
# 0           4.398230e-09                      No               N
# 1           4.398230e-09                      No               N
# 2           4.398230e-09                      No               N
# 3           4.398230e-09                      No               N
# 4           4.398230e-09                      No               N
# ...                  ...                     ...             ...
# 3898        2.469675e-06                      No             Yes
# 3899        2.469675e-06                      No             Yes
# 3900        2.469675e-06                      No             Yes
# 3901        2.469675e-06                      No             Yes
# 3902        2.469675e-06                      No             Yes
#
#      Polymer Validated? Shape Validated Particle Source Sodium Azide Present?  \
# 0                     N               N      commercial                    No
# 1                     N               N      commercial                    No
# 2                     N               N      commercial                    No
# 3                     N               N      commercial                    No
# 4                     N               N      commercial                    No
# ...                 ...             ...             ...                   ...
# 3898                 No              No      commercial                   Yes
# 3899                 No              No      commercial                   Yes
# 3900                 No              No      commercial                   Yes
# 3901                 No              No      commercial                   Yes
# 3902                 No              No      commercial                   Yes
#
#      Screened for Chemical Contamination? Particle Cleaning? Solvent Rinse  \
# 0                                       N        not_cleaned          none
# 1                                       N        not_cleaned          none
# 2                                       N        not_cleaned          none
# 3                                       N        not_cleaned          none
# 4                                       N        not_cleaned          none
# ...                                   ...                ...           ...
# 3898                                   No        not_cleaned          none
# 3899                                   No        not_cleaned          none
# 3900                                   No        not_cleaned          none
# 3901                                   No        not_cleaned          none
# 3902                                   No        not_cleaned          none
#
#      Background Contamination Monitored? Concentration Validated?  \
# 0                                      N                        N
# 1                                      N                        N
# 2                                      N                        N
# 3                                      N                        N
# 4                                      N                        N
# ...                                  ...                      ...
# 3898                                  No                       No
# 3899                                  No                       No
# 3900                                  No                       No
# 3901                                  No                       No
# 3902                                  No                       No
#
#      Particle Behavior Uptake Validated?          Uptake Validation Method  \
# 0        Not Evaluated                 Y  microscopy flourescent particles
# 1        Not Evaluated                 Y  microscopy flourescent particles
# 2        Not Evaluated                 Y  microscopy flourescent particles
# 3        Not Evaluated                 Y  microscopy flourescent particles
# 4        Not Evaluated                 Y  microscopy flourescent particles
# ...                ...               ...                               ...
# 3898              none               Yes                        microscopy
# 3899              none               Yes                        microscopy
# 3900              none               Yes                        microscopy
# 3901              none               Yes                        microscopy
# 3902              none               Yes                        microscopy
#
#      Tissue Distribution Organisms Fed?
# 0                    gut            Yes
# 1                    gut            Yes
# 2                    gut            Yes
# 3                    gut            Yes
# 4                    gut            Yes
# ...                  ...            ...
# 3898     anterior kidney             No
# 3899     anterior kidney             No
# 3900     anterior kidney             No
# 3901     anterior kidney             No
# 3902     anterior kidney             No
#
# [3903 rows x 76 columns]

# %%
(tomex["Plotted Dose Values"] == tomex["Unaligned Dose Values"]).all()
# Out:
# np.True_

# %%
tomex["Sample Size"].value_counts()
# Out:
# Sample Size
# 1                1054
# 10                502
# 20                483
# 5                 260
# 6                 150
# 30                149
# 4                 141
# 16                115
# 3                 110
# 8                 104
# 15                 96
# 50                 74
# 1000               49
# 24                 47
# 300                47
# 200                39
# 100                38
# 2                  35
# 10^7 cells/mL      35
# 14                 24
# 70                 24
# 9                  17
# 60                 14
# 40                 12
# 12.5               12
# 17.5               12
# 65                  8
# 370                 8
# 17                  7
# 18                  5
# 11                  4
# 1500                4
# 12                  4
# 23                  4
# 25                  4
# 68                  2
# 172                 2
# 58                  2
# 19                  2
# 90                  2
# 144                 2
# 28                  2
# 900                 2
# 21                  1
# Name: count, dtype: int64

# %%
# Función para convertir a float; si no se puede, devuelve NaN
def parse_sample_size(x):
    try:
        return float(x)
    except:
        return np.nan

# Crear columna numérica
tomex["sample_size_num"] = tomex["Sample Size"].apply(parse_sample_size)

# Filtrar solo filas con números positivos
tomex_clean = tomex[tomex["sample_size_num"].notna() & (tomex["sample_size_num"] > 0)].copy()

tomex_clean["dosis_per_individual"] = tomex_clean["Unaligned Dose Values"] / tomex_clean["sample_size_num"]

# %%
# Nos quedeamos con los experimentos en los que se ha observado efecto

tomex_effect = tomex_clean[tomex_clean["Effect"] == "Yes"]

# %%
tomex_effect["dosis_per_individual"].describe()
# Out:
# count    1.231000e+03
# mean     1.328518e+08
# std      2.670751e+09
# min      8.461820e-05
# 25%      5.000000e-01
# 50%      2.600000e+01
# 75%      7.500000e+02
# max      8.120000e+10
# Name: dosis_per_individual, dtype: float64

# %%
## Cálculo de umbral ecotoxicologico. Cuando no existe criterio externo el percentil 50 es el default metodológico

eco_tox_threshold = tomex_effect["dosis_per_individual"].median() # Calcula mediana de valores de dosis tóxicas
log_eco_tox_threshold = np.log10(eco_tox_threshold)
log_eco_tox_threshold
# Out:
# np.float64(1.414973347970818)

# %% [markdown]
# Hemos calculado un valor central de dosis tóxica
# (el 50 % de los valores están por debajo y el 50 % por encima)
# Se utilizará como valor de referencia estadístico para comparar patrones relativos de riesgo
#
# Tomamos la dosis tóxica mediana observada en Tomex como un umbral de referencia y la transformamos a escala logarítmica para su análisis
#
# En ecotoxicología esto se usa para:
#
# clasificar (alto vs bajo riesgo relativo)
#
# comparar especies
#
# analizar patrones

# %%
# Convertimos unidades de NOAA (particles/m3 -> particles/ml)
iucn_noaa["mp_particles_ml"] = (
    iucn_noaa["mp_effective_m3"] / 1_000_000
)

# %% [markdown]
# Para evitar ver ceros, normal al dividir entre un millón, convertimos los valores a escala logarítmica

# %%
iucn_noaa["log_mp_particles_ml"] = np.log10(
    iucn_noaa["mp_particles_ml"] + 1e-12
)

# %%
# Presión tóxica relativa
iucn_noaa["log_toxic_pressure"] = (
    iucn_noaa["log_mp_particles_ml"] - log_eco_tox_threshold
)

# %% [markdown]
# La presión tóxica relativa se calculó como la diferencia entre la concentración logarítmica de microplásticos y el umbral ecotoxicológico de referencia, representando el número de órdenes de magnitud por los que la exposición se sitúa por encima o por debajo del valor central de toxicidad

# %% [markdown]
# Las concentraciones ambientales de microplásticos se sitúan, en general, por debajo de las dosis experimentales reportadas en estudios ecotoxicológicos. Por tanto, los valores de presión tóxica relativa resultan negativos y se interpretan como una medida de proximidad al umbral, no como evidencia de toxicidad directa

# %% [markdown]
# Los límites se establecieron de forma exploratoria para diferenciar especies más o menos próximas al umbral ecotoxicológico, dada la escala logarítmica de las concentraciones

# %%
iucn_noaa
# Out:
#                   sci_name redlistCategory                           geometry  \
# 0         Hubbsina turneri              CR   POINT (-11296646.266 2258169.64)
# 1         Hubbsina turneri              CR   POINT (-11329797.21 2252382.257)
# 2         Hubbsina turneri              CR  POINT (-11330943.801 2252583.424)
# 3      Ictalurus mexicanus              VU  POINT (-11060055.613 2509223.803)
# 4      Ictalurus mexicanus              VU  POINT (-11054025.436 2511525.235)
# ...                    ...             ...                                ...
# 70268  Macrobrachium thysi              VU     POINT (-334164.413 573406.106)
# 70269  Macrobrachium thysi              VU     POINT (-391958.153 613149.338)
# 70270  Macrobrachium thysi              VU     POINT (-391057.579 612084.684)
# 70271  Macrobrachium thysi              VU     POINT (-458950.223 602254.212)
# 70272  Macrobrachium thysi              VU      POINT (-451061.011 600278.45)
#
#        iucn_id  vuln  index_right  mp_pieces_m3         dist_m  distance_km  \
# 0            0     4        13104   2115.655853  244627.454273   244.627454
# 1            1     4        13104   2115.655853  237016.489842   237.016490
# 2            2     4        13104   2115.655853  237235.709534   237.235710
# 3            3     2        13032   2820.874471  176956.192726   176.956193
# 4            4     2        13032   2820.874471  170585.675721   170.585676
# ...        ...   ...          ...           ...            ...          ...
# 70268    70268     2        11468      0.038661  959001.335033   959.001335
# 70269    70269     2        11468      0.038661  929073.410690   929.073411
# 70270    70270     2        11468      0.038661  929269.937379   929.269937
# 70271    70271     2        11468      0.038661  866968.071829   866.968072
# 70272    70272     2        11468      0.038661  872433.478446   872.433478
#
#        mp_effective_m3  mp_particles_ml  log_mp_particles_ml  \
# 0         1.587223e+01     1.587223e-05            -4.799362
# 1         1.848187e+01     1.848187e-05            -4.733254
# 2         1.840102e+01     1.840102e-05            -4.735158
# 3         8.191469e+01     8.191469e-05            -4.086638
# 4         9.304551e+01     9.304551e-05            -4.031305
# ...                ...              ...                  ...
# 70268     1.809228e-10     1.809228e-16           -11.999921
# 70269     3.291880e-10     3.291880e-16           -11.999857
# 70270     3.278966e-10     3.278966e-16           -11.999858
# 70271     1.139946e-09     1.139946e-15           -11.999505
# 70272     1.021909e-09     1.021909e-15           -11.999556
#
#        log_toxic_pressure
# 0               -6.214335
# 1               -6.148227
# 2               -6.150131
# 3               -5.501612
# 4               -5.446278
# ...                   ...
# 70268          -13.414895
# 70269          -13.414830
# 70270          -13.414831
# 70271          -13.414479
# 70272          -13.414530
#
# [70273 rows x 13 columns]

# %% [markdown]
# # Paso 6. Cálculo del riesgo ecológico

# %%
iucn_noaa["toxic_pressure"] = 10 ** iucn_noaa["log_toxic_pressure"]

# %%
iucn_noaa["eco_risk_score"] = (
    iucn_noaa["toxic_pressure"] *
    iucn_noaa["vuln"]
)

iucn_noaa
# Out:
#                   sci_name redlistCategory                           geometry  \
# 0         Hubbsina turneri              CR   POINT (-11296646.266 2258169.64)
# 1         Hubbsina turneri              CR   POINT (-11329797.21 2252382.257)
# 2         Hubbsina turneri              CR  POINT (-11330943.801 2252583.424)
# 3      Ictalurus mexicanus              VU  POINT (-11060055.613 2509223.803)
# 4      Ictalurus mexicanus              VU  POINT (-11054025.436 2511525.235)
# ...                    ...             ...                                ...
# 70268  Macrobrachium thysi              VU     POINT (-334164.413 573406.106)
# 70269  Macrobrachium thysi              VU     POINT (-391958.153 613149.338)
# 70270  Macrobrachium thysi              VU     POINT (-391057.579 612084.684)
# 70271  Macrobrachium thysi              VU     POINT (-458950.223 602254.212)
# 70272  Macrobrachium thysi              VU      POINT (-451061.011 600278.45)
#
#        iucn_id  vuln  index_right  mp_pieces_m3         dist_m  distance_km  \
# 0            0     4        13104   2115.655853  244627.454273   244.627454
# 1            1     4        13104   2115.655853  237016.489842   237.016490
# 2            2     4        13104   2115.655853  237235.709534   237.235710
# 3            3     2        13032   2820.874471  176956.192726   176.956193
# 4            4     2        13032   2820.874471  170585.675721   170.585676
# ...        ...   ...          ...           ...            ...          ...
# 70268    70268     2        11468      0.038661  959001.335033   959.001335
# 70269    70269     2        11468      0.038661  929073.410690   929.073411
# 70270    70270     2        11468      0.038661  929269.937379   929.269937
# 70271    70271     2        11468      0.038661  866968.071829   866.968072
# 70272    70272     2        11468      0.038661  872433.478446   872.433478
#
#        mp_effective_m3  mp_particles_ml  log_mp_particles_ml  \
# 0         1.587223e+01     1.587223e-05            -4.799362
# 1         1.848187e+01     1.848187e-05            -4.733254
# 2         1.840102e+01     1.840102e-05            -4.735158
# 3         8.191469e+01     8.191469e-05            -4.086638
# 4         9.304551e+01     9.304551e-05            -4.031305
# ...                ...              ...                  ...
# 70268     1.809228e-10     1.809228e-16           -11.999921
# 70269     3.291880e-10     3.291880e-16           -11.999857
# 70270     3.278966e-10     3.278966e-16           -11.999858
# 70271     1.139946e-09     1.139946e-15           -11.999505
# 70272     1.021909e-09     1.021909e-15           -11.999556
#
#        log_toxic_pressure  toxic_pressure  eco_risk_score
# 0               -6.214335    6.104704e-07    2.441882e-06
# 1               -6.148227    7.108413e-07    2.843365e-06
# 2               -6.150131    7.077315e-07    2.830926e-06
# 3               -5.501612    3.150565e-06    6.301130e-06
# 4               -5.446278    3.578673e-06    7.157347e-06
# ...                   ...             ...             ...
# 70268          -13.414895    3.846850e-14    7.693699e-14
# 70269          -13.414830    3.847420e-14    7.694840e-14
# 70270          -13.414831    3.847415e-14    7.694830e-14
# 70271          -13.414479    3.850538e-14    7.701077e-14
# 70272          -13.414530    3.850084e-14    7.700169e-14
#
# [70273 rows x 15 columns]

# %%
iucn_noaa["eco_risk_score"].describe()
# Out:
# count    7.027300e+04
# mean     3.467346e-06
# std      1.168741e-04
# min      3.846154e-14
# 25%      7.692308e-14
# 50%      7.181275e-12
# 75%      1.849328e-10
# max      1.451458e-02
# Name: eco_risk_score, dtype: float64

# %% [markdown]
# # Paso 7. Crear Dataset

# %%
iucn_noaa.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 70273 entries, 0 to 70272
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   sci_name             70273 non-null  object
#  1   redlistCategory      70273 non-null  object
#  2   geometry             70273 non-null  geometry
#  3   iucn_id              70273 non-null  int64
#  4   vuln                 70273 non-null  int64
#  5   index_right          70273 non-null  int64
#  6   mp_pieces_m3         70273 non-null  float64
#  7   dist_m               70273 non-null  float64
#  8   distance_km          70273 non-null  float64
#  9   mp_effective_m3      70273 non-null  float64
#  10  mp_particles_ml      70273 non-null  float64
#  11  log_mp_particles_ml  70273 non-null  float64
#  12  log_toxic_pressure   70273 non-null  float64
#  13  toxic_pressure       70273 non-null  float64
#  14  eco_risk_score       70273 non-null  float64
# dtypes: float64(9), geometry(1), int64(3), object(2)
# memory usage: 8.6+ MB

# %%
# Escalamos los valores para que sean más intuitivos de riesgo ecológico
scaler = MinMaxScaler(feature_range=(0, 100))



iucn_noaa["eco_risk_index"] = scaler.fit_transform(
    iucn_noaa[["eco_risk_score"]]
)

# %%
iucn_noaa
# Out:
#                   sci_name redlistCategory                           geometry  \
# 0         Hubbsina turneri              CR   POINT (-11296646.266 2258169.64)
# 1         Hubbsina turneri              CR   POINT (-11329797.21 2252382.257)
# 2         Hubbsina turneri              CR  POINT (-11330943.801 2252583.424)
# 3      Ictalurus mexicanus              VU  POINT (-11060055.613 2509223.803)
# 4      Ictalurus mexicanus              VU  POINT (-11054025.436 2511525.235)
# ...                    ...             ...                                ...
# 70268  Macrobrachium thysi              VU     POINT (-334164.413 573406.106)
# 70269  Macrobrachium thysi              VU     POINT (-391958.153 613149.338)
# 70270  Macrobrachium thysi              VU     POINT (-391057.579 612084.684)
# 70271  Macrobrachium thysi              VU     POINT (-458950.223 602254.212)
# 70272  Macrobrachium thysi              VU      POINT (-451061.011 600278.45)
#
#        iucn_id  vuln  index_right  mp_pieces_m3         dist_m  distance_km  \
# 0            0     4        13104   2115.655853  244627.454273   244.627454
# 1            1     4        13104   2115.655853  237016.489842   237.016490
# 2            2     4        13104   2115.655853  237235.709534   237.235710
# 3            3     2        13032   2820.874471  176956.192726   176.956193
# 4            4     2        13032   2820.874471  170585.675721   170.585676
# ...        ...   ...          ...           ...            ...          ...
# 70268    70268     2        11468      0.038661  959001.335033   959.001335
# 70269    70269     2        11468      0.038661  929073.410690   929.073411
# 70270    70270     2        11468      0.038661  929269.937379   929.269937
# 70271    70271     2        11468      0.038661  866968.071829   866.968072
# 70272    70272     2        11468      0.038661  872433.478446   872.433478
#
#        mp_effective_m3  mp_particles_ml  log_mp_particles_ml  \
# 0         1.587223e+01     1.587223e-05            -4.799362
# 1         1.848187e+01     1.848187e-05            -4.733254
# 2         1.840102e+01     1.840102e-05            -4.735158
# 3         8.191469e+01     8.191469e-05            -4.086638
# 4         9.304551e+01     9.304551e-05            -4.031305
# ...                ...              ...                  ...
# 70268     1.809228e-10     1.809228e-16           -11.999921
# 70269     3.291880e-10     3.291880e-16           -11.999857
# 70270     3.278966e-10     3.278966e-16           -11.999858
# 70271     1.139946e-09     1.139946e-15           -11.999505
# 70272     1.021909e-09     1.021909e-15           -11.999556
#
#        log_toxic_pressure  toxic_pressure  eco_risk_score  eco_risk_index
# 0               -6.214335    6.104704e-07    2.441882e-06    1.682364e-02
# 1               -6.148227    7.108413e-07    2.843365e-06    1.958971e-02
# 2               -6.150131    7.077315e-07    2.830926e-06    1.950401e-02
# 3               -5.501612    3.150565e-06    6.301130e-06    4.341240e-02
# 4               -5.446278    3.578673e-06    7.157347e-06    4.931141e-02
# ...                   ...             ...             ...             ...
# 70268          -13.414895    3.846850e-14    7.693699e-14    2.650813e-10
# 70269          -13.414830    3.847420e-14    7.694840e-14    2.651599e-10
# 70270          -13.414831    3.847415e-14    7.694830e-14    2.651592e-10
# 70271          -13.414479    3.850538e-14    7.701077e-14    2.655896e-10
# 70272          -13.414530    3.850084e-14    7.700169e-14    2.655270e-10
#
# [70273 rows x 16 columns]

# %%
iucn_noaa["eco_risk_index"].describe()
# Out:
# count    7.027300e+04
# mean     2.388870e-02
# std      8.052183e-01
# min      0.000000e+00
# 25%      2.649855e-10
# 50%      4.921128e-08
# 75%      1.273852e-06
# max      1.000000e+02
# Name: eco_risk_index, dtype: float64

# %%
q20, q50, q80 = iucn_noaa["eco_risk_index"].quantile([0.2, 0.5, 0.8])
def risk_class(x):
    if x <= q20:
        return "negligible pressure"
    elif x <= q50:
        return "low relative pressure"
    elif x <= q80:
        return "moderate relative pressure"
    else:
        return "elevated relative pressure"

iucn_noaa["eco_risk_class"] = iucn_noaa["eco_risk_index"].apply(risk_class)

iucn_noaa["eco_risk_class"].value_counts()
# Out:
# eco_risk_class
# negligible pressure           21981
# moderate relative pressure    21081
# elevated relative pressure    14055
# low relative pressure         13156
# Name: count, dtype: int64

# %%
iucn_noaa.columns
# Out:
# Index(['sci_name', 'redlistCategory', 'geometry', 'iucn_id', 'vuln',
#        'index_right', 'mp_pieces_m3', 'dist_m', 'distance_km',
#        'mp_effective_m3', 'mp_particles_ml', 'log_mp_particles_ml',
#        'log_toxic_pressure', 'toxic_pressure', 'eco_risk_score',
#        'eco_risk_index', 'eco_risk_class'],
#       dtype='object')

# %%
iucn_noaa["log_distance_km"] = np.log10(iucn_noaa["distance_km"] + 1)

# %%
new_order = [
    "iucn_id",
    "sci_name",
    "redlistCategory",
    "vuln",
    "geometry",
    "dist_m",
    "distance_km",
    "log_distance_km",
    "index_right",
    "mp_pieces_m3",
    "mp_effective_m3",
    "mp_particles_ml",
    "log_mp_particles_ml",
    "log_toxic_pressure",
    "toxic_pressure",
    "eco_risk_score",
    "eco_risk_index",
    "eco_risk_class",
]

dataset = iucn_noaa[new_order]

# %%
dataset
# Out:
#        iucn_id             sci_name redlistCategory  vuln  \
# 0            0     Hubbsina turneri              CR     4
# 1            1     Hubbsina turneri              CR     4
# 2            2     Hubbsina turneri              CR     4
# 3            3  Ictalurus mexicanus              VU     2
# 4            4  Ictalurus mexicanus              VU     2
# ...        ...                  ...             ...   ...
# 70268    70268  Macrobrachium thysi              VU     2
# 70269    70269  Macrobrachium thysi              VU     2
# 70270    70270  Macrobrachium thysi              VU     2
# 70271    70271  Macrobrachium thysi              VU     2
# 70272    70272  Macrobrachium thysi              VU     2
#
#                                 geometry         dist_m  distance_km  \
# 0       POINT (-11296646.266 2258169.64)  244627.454273   244.627454
# 1       POINT (-11329797.21 2252382.257)  237016.489842   237.016490
# 2      POINT (-11330943.801 2252583.424)  237235.709534   237.235710
# 3      POINT (-11060055.613 2509223.803)  176956.192726   176.956193
# 4      POINT (-11054025.436 2511525.235)  170585.675721   170.585676
# ...                                  ...            ...          ...
# 70268     POINT (-334164.413 573406.106)  959001.335033   959.001335
# 70269     POINT (-391958.153 613149.338)  929073.410690   929.073411
# 70270     POINT (-391057.579 612084.684)  929269.937379   929.269937
# 70271     POINT (-458950.223 602254.212)  866968.071829   866.968072
# 70272      POINT (-451061.011 600278.45)  872433.478446   872.433478
#
#        log_distance_km  index_right  mp_pieces_m3  mp_effective_m3  \
# 0             2.390277        13104   2115.655853     1.587223e+01
# 1             2.376607        13104   2115.655853     1.848187e+01
# 2             2.377007        13104   2115.655853     1.840102e+01
# 3             2.250313        13032   2820.874471     8.191469e+01
# 4             2.234481        13032   2820.874471     9.304551e+01
# ...                ...          ...           ...              ...
# 70268         2.982272        11468      0.038661     1.809228e-10
# 70269         2.968517        11468      0.038661     3.291880e-10
# 70270         2.968609        11468      0.038661     3.278966e-10
# 70271         2.938504        11468      0.038661     1.139946e-09
# 70272         2.941230        11468      0.038661     1.021909e-09
#
#        mp_particles_ml  log_mp_particles_ml  log_toxic_pressure  \
# 0         1.587223e-05            -4.799362           -6.214335
# 1         1.848187e-05            -4.733254           -6.148227
# 2         1.840102e-05            -4.735158           -6.150131
# 3         8.191469e-05            -4.086638           -5.501612
# 4         9.304551e-05            -4.031305           -5.446278
# ...                ...                  ...                 ...
# 70268     1.809228e-16           -11.999921          -13.414895
# 70269     3.291880e-16           -11.999857          -13.414830
# 70270     3.278966e-16           -11.999858          -13.414831
# 70271     1.139946e-15           -11.999505          -13.414479
# 70272     1.021909e-15           -11.999556          -13.414530
#
#        toxic_pressure  eco_risk_score  eco_risk_index  \
# 0        6.104704e-07    2.441882e-06    1.682364e-02
# 1        7.108413e-07    2.843365e-06    1.958971e-02
# 2        7.077315e-07    2.830926e-06    1.950401e-02
# 3        3.150565e-06    6.301130e-06    4.341240e-02
# 4        3.578673e-06    7.157347e-06    4.931141e-02
# ...               ...             ...             ...
# 70268    3.846850e-14    7.693699e-14    2.650813e-10
# 70269    3.847420e-14    7.694840e-14    2.651599e-10
# 70270    3.847415e-14    7.694830e-14    2.651592e-10
# 70271    3.850538e-14    7.701077e-14    2.655896e-10
# 70272    3.850084e-14    7.700169e-14    2.655270e-10
#
#                    eco_risk_class
# 0      elevated relative pressure
# 1      elevated relative pressure
# 2      elevated relative pressure
# 3      elevated relative pressure
# 4      elevated relative pressure
# ...                           ...
# 70268       low relative pressure
# 70269       low relative pressure
# 70270       low relative pressure
# 70271       low relative pressure
# 70272       low relative pressure
#
# [70273 rows x 18 columns]

# %%
iucn_noaa.sort_values("eco_risk_index", ascending=False).head(10)
# Out:
#                      sci_name redlistCategory  \
# 60583        Pteroptyx valida              VU
# 60424      Pteroptyx malaccae              VU
# 28116   Amphicnemis valentini              EN
# 12695   Desmophyllum pertusum              VU
# 23553   Desmophyllum pertusum              VU
# 8095   Tetrathemis flavescens              NT
# 60580        Pteroptyx valida              VU
# 60421      Pteroptyx malaccae              VU
# 60581        Pteroptyx valida              VU
# 60422      Pteroptyx malaccae              VU
#
#                                geometry  iucn_id  vuln  index_right  \
# 60583  POINT (11441618.307 1337110.852)    60583     2        13002
# 60424  POINT (11441618.307 1337110.852)    60424     2        13002
# 28116  POINT (11479633.245 1290970.211)    28116     3        13003
# 12695  POINT (-1833431.937 3257802.019)    12695     2        12849
# 23553  POINT (-1833431.937 3256540.458)    23553     2        12849
# 8095   POINT (11477841.001 1308395.567)     8095     1        13003
# 60580  POINT (11364909.827 1405652.041)    60580     2        12996
# 60421  POINT (11364909.827 1405652.041)    60421     2        12996
# 60581  POINT (11377445.626 1388646.967)    60581     2        12996
# 60422  POINT (11377445.626 1388646.967)    60422     2        12996
#
#        mp_pieces_m3        dist_m  distance_km  mp_effective_m3  \
# 60583      200000.0   2910.702163     2.910702    188689.597427
# 60424      200000.0   2910.702163     2.910702    188689.597427
# 28116      352000.0  56700.118105    56.700118    113253.516369
# 12695      110480.0  11249.668926    11.249669     88220.655997
# 23553      110480.0  12426.737886    12.426738     86168.075167
# 8095       352000.0  43611.720873    43.611721    147141.801538
# 60580       72480.0   6168.757726     6.168758     64067.390582
# 60421       72480.0   6168.757726     6.168758     64067.390582
# 60581       72480.0  19389.994342    19.389994     49181.167454
# 60422       72480.0  19389.994342    19.389994     49181.167454
#
#        mp_particles_ml  log_mp_particles_ml  log_toxic_pressure  \
# 60583         0.188690            -0.724252           -2.139225
# 60424         0.188690            -0.724252           -2.139225
# 28116         0.113254            -0.945948           -2.360922
# 12695         0.088221            -1.054430           -2.469403
# 23553         0.086168            -1.064654           -2.479627
# 8095          0.147142            -0.832264           -2.247237
# 60580         0.064067            -1.193363           -2.608336
# 60421         0.064067            -1.193363           -2.608336
# 60581         0.049181            -1.308201           -2.723175
# 60422         0.049181            -1.308201           -2.723175
#
#        toxic_pressure  eco_risk_score  eco_risk_index  \
# 60583        0.007257        0.014515      100.000000
# 60424        0.007257        0.014515      100.000000
# 28116        0.004356        0.013068       90.031606
# 12695        0.003393        0.006786       46.754382
# 23553        0.003314        0.006628       45.666574
# 8095         0.005659        0.005659       38.990438
# 60580        0.002464        0.004928       33.953854
# 60421        0.002464        0.004928       33.953854
# 60581        0.001892        0.003783       26.064589
# 60422        0.001892        0.003783       26.064589
#
#                    eco_risk_class  log_distance_km
# 60583  elevated relative pressure         0.592255
# 60424  elevated relative pressure         0.592255
# 28116  elevated relative pressure         1.761177
# 12695  elevated relative pressure         1.088124
# 23553  elevated relative pressure         1.127971
# 8095   elevated relative pressure         1.649449
# 60580  elevated relative pressure         0.855444
# 60421  elevated relative pressure         0.855444
# 60581  elevated relative pressure         1.309417
# 60422  elevated relative pressure         1.309417

# %%
# Guardar

dataset.to_file("../data/dataset.gpkg", layer="ecol_risk", driver="GPKG")
dataset.to_parquet("../data/dataset.parquet")

dataset_csv = dataset.copy()
dataset_csv["geometry"] = dataset_csv.geometry.to_wkt()
dataset_csv.to_csv("../data/dataset_csv.csv", index=False)
# Out:
# /tmp/ipykernel_3000/44233542.py:7: UserWarning: Geometry column does not contain geometry.
#   dataset_csv["geometry"] = dataset_csv.geometry.to_wkt()
